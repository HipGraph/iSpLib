# %%
{
	"name": "RuntimeError",
	"message": "Only `pass` statement or `...` can be the body of overload declaration:\n@torch.jit._overload  # noqa: F811\ndef matmul(src, other, reduce):  # noqa: F811\n    print(\"inside the sparse package matmul function\") <- Expecting `pass` or `...` here!\n\nExample usage of overload function:\n@torch.jit._overload\ndef my_function(x: type0) -> type0: # decl 1\n    pass\n\n@torch.jit._overload\ndef my_function(x: type1) -> type1: # decl 2\n    pass\n\ndef my_function(x):                 # implementation\n    if isinstance(x, type0):\n        return x\n    elif isinstance(x, type1):\n        return x\n",
	"stack": "\u001b[1;31m---------------------------------------------------------------------------\u001b[0m\n\u001b[1;31mRuntimeError\u001b[0m                              Traceback (most recent call last)\n\u001b[1;32md:\\Github\\SpGLL\\Graph_Neural_Networks.ipynb Cell 5\u001b[0m in \u001b[0;36m<cell line: 1>\u001b[1;34m()\u001b[0m\n\u001b[1;32m----> <a href='vscode-notebook-cell:/d%3A/Github/SpGLL/Graph_Neural_Networks.ipynb#ch0000004?line=0'>1</a>\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39mtorch_geometric\u001b[39;00m\u001b[39m.\u001b[39;00m\u001b[39mdatasets\u001b[39;00m \u001b[39mimport\u001b[39;00m Planetoid\n\u001b[0;32m      <a href='vscode-notebook-cell:/d%3A/Github/SpGLL/Graph_Neural_Networks.ipynb#ch0000004?line=2'>3</a>\u001b[0m dataset \u001b[39m=\u001b[39m Planetoid(root\u001b[39m=\u001b[39m\u001b[39m'\u001b[39m\u001b[39m/tmp/Cora\u001b[39m\u001b[39m'\u001b[39m, name\u001b[39m=\u001b[39m\u001b[39m'\u001b[39m\u001b[39mCora\u001b[39m\u001b[39m'\u001b[39m)\n\nFile \u001b[1;32md:\\Github\\SpGLL\\venv\\lib\\site-packages\\torch_geometric\\__init__.py:4\u001b[0m, in \u001b[0;36m<module>\u001b[1;34m\u001b[0m\n\u001b[0;32m      1\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39mtypes\u001b[39;00m \u001b[39mimport\u001b[39;00m ModuleType\n\u001b[0;32m      2\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39mimportlib\u001b[39;00m \u001b[39mimport\u001b[39;00m import_module\n\u001b[1;32m----> 4\u001b[0m \u001b[39mimport\u001b[39;00m \u001b[39mtorch_geometric\u001b[39;00m\u001b[39m.\u001b[39;00m\u001b[39mdata\u001b[39;00m\n\u001b[0;32m      5\u001b[0m \u001b[39mimport\u001b[39;00m \u001b[39mtorch_geometric\u001b[39;00m\u001b[39m.\u001b[39;00m\u001b[39mloader\u001b[39;00m\n\u001b[0;32m      6\u001b[0m \u001b[39mimport\u001b[39;00m \u001b[39mtorch_geometric\u001b[39;00m\u001b[39m.\u001b[39;00m\u001b[39mtransforms\u001b[39;00m\n\nFile \u001b[1;32md:\\Github\\SpGLL\\venv\\lib\\site-packages\\torch_geometric\\data\\__init__.py:1\u001b[0m, in \u001b[0;36m<module>\u001b[1;34m\u001b[0m\n\u001b[1;32m----> 1\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39m.\u001b[39;00m\u001b[39mdata\u001b[39;00m \u001b[39mimport\u001b[39;00m Data\n\u001b[0;32m      2\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39m.\u001b[39;00m\u001b[39mhetero_data\u001b[39;00m \u001b[39mimport\u001b[39;00m HeteroData\n\u001b[0;32m      3\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39m.\u001b[39;00m\u001b[39mtemporal\u001b[39;00m \u001b[39mimport\u001b[39;00m TemporalData\n\nFile \u001b[1;32md:\\Github\\SpGLL\\venv\\lib\\site-packages\\torch_geometric\\data\\data.py:20\u001b[0m, in \u001b[0;36m<module>\u001b[1;34m\u001b[0m\n\u001b[0;32m     18\u001b[0m \u001b[39mimport\u001b[39;00m \u001b[39mtorch\u001b[39;00m\n\u001b[0;32m     19\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39mtorch\u001b[39;00m \u001b[39mimport\u001b[39;00m Tensor\n\u001b[1;32m---> 20\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39mthe_sparse_package\u001b[39;00m \u001b[39mimport\u001b[39;00m SparseTensor\n\u001b[0;32m     22\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39mtorch_geometric\u001b[39;00m\u001b[39m.\u001b[39;00m\u001b[39mdata\u001b[39;00m\u001b[39m.\u001b[39;00m\u001b[39mfeature_store\u001b[39;00m \u001b[39mimport\u001b[39;00m (\n\u001b[0;32m     23\u001b[0m     FeatureStore,\n\u001b[0;32m     24\u001b[0m     FeatureTensorType,\n\u001b[0;32m     25\u001b[0m     TensorAttr,\n\u001b[0;32m     26\u001b[0m     _field_status,\n\u001b[0;32m     27\u001b[0m )\n\u001b[0;32m     28\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39mtorch_geometric\u001b[39;00m\u001b[39m.\u001b[39;00m\u001b[39mdata\u001b[39;00m\u001b[39m.\u001b[39;00m\u001b[39mgraph_store\u001b[39;00m \u001b[39mimport\u001b[39;00m (\n\u001b[0;32m     29\u001b[0m     EDGE_LAYOUT_TO_ATTR_NAME,\n\u001b[0;32m     30\u001b[0m     EdgeAttr,\n\u001b[1;32m   (...)\u001b[0m\n\u001b[0;32m     34\u001b[0m     edge_tensor_type_to_adj_type,\n\u001b[0;32m     35\u001b[0m )\n\nFile \u001b[1;32md:\\Github\\SpGLL\\venv\\lib\\site-packages\\the_sparse_package\\__init__.py:52\u001b[0m, in \u001b[0;36m<module>\u001b[1;34m\u001b[0m\n\u001b[0;32m     50\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39m.\u001b[39;00m\u001b[39mmul\u001b[39;00m \u001b[39mimport\u001b[39;00m mul, mul_, mul_nnz, mul_nnz_  \u001b[39m# noqa\u001b[39;00m\n\u001b[0;32m     51\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39m.\u001b[39;00m\u001b[39mreduce\u001b[39;00m \u001b[39mimport\u001b[39;00m \u001b[39msum\u001b[39m, mean, \u001b[39mmin\u001b[39m, \u001b[39mmax\u001b[39m  \u001b[39m# noqa\u001b[39;00m\n\u001b[1;32m---> 52\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39m.\u001b[39;00m\u001b[39mmatmul\u001b[39;00m \u001b[39mimport\u001b[39;00m matmul  \u001b[39m# noqa\u001b[39;00m\n\u001b[0;32m     53\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39m.\u001b[39;00m\u001b[39mcat\u001b[39;00m \u001b[39mimport\u001b[39;00m cat  \u001b[39m# noqa\u001b[39;00m\n\u001b[0;32m     54\u001b[0m \u001b[39mfrom\u001b[39;00m \u001b[39m.\u001b[39;00m\u001b[39mrw\u001b[39;00m \u001b[39mimport\u001b[39;00m random_walk  \u001b[39m# noqa\u001b[39;00m\n\nFile \u001b[1;32md:\\Github\\SpGLL\\venv\\lib\\site-packages\\the_sparse_package\\matmul.py:125\u001b[0m, in \u001b[0;36m<module>\u001b[1;34m\u001b[0m\n\u001b[0;32m    120\u001b[0m     \u001b[39melse\u001b[39;00m:\n\u001b[0;32m    121\u001b[0m         \u001b[39mraise\u001b[39;00m \u001b[39mValueError\u001b[39;00m\n\u001b[0;32m    124\u001b[0m \u001b[39m@torch\u001b[39;49m\u001b[39m.\u001b[39;49mjit\u001b[39m.\u001b[39;49m_overload  \u001b[39m# noqa: F811\u001b[39;49;00m\n\u001b[1;32m--> 125\u001b[0m \u001b[39mdef\u001b[39;49;00m \u001b[39mmatmul\u001b[39;49m(src, other, reduce):  \u001b[39m# noqa: F811\u001b[39;49;00m\n\u001b[0;32m    126\u001b[0m     \u001b[39mprint\u001b[39;49m(\u001b[39m\"\u001b[39;49m\u001b[39minside the sparse package matmul function\u001b[39;49m\u001b[39m\"\u001b[39;49m)\n\u001b[0;32m    127\u001b[0m     \u001b[39m# type: (SparseTensor, torch.Tensor, str) -> torch.Tensor\u001b[39;49;00m\n\nFile \u001b[1;32md:\\Github\\SpGLL\\venv\\lib\\site-packages\\torch\\_jit_internal.py:769\u001b[0m, in \u001b[0;36m_overload\u001b[1;34m(func)\u001b[0m\n\u001b[0;32m    768\u001b[0m \u001b[39mdef\u001b[39;00m \u001b[39m_overload\u001b[39m(func):\n\u001b[1;32m--> 769\u001b[0m     _check_overload_body(func)\n\u001b[0;32m    770\u001b[0m     qual_name \u001b[39m=\u001b[39m _qualified_name(func)\n\u001b[0;32m    771\u001b[0m     \u001b[39mglobal\u001b[39;00m _overloaded_fns\n\nFile \u001b[1;32md:\\Github\\SpGLL\\venv\\lib\\site-packages\\torch\\_jit_internal.py:766\u001b[0m, in \u001b[0;36m_check_overload_body\u001b[1;34m(func)\u001b[0m\n\u001b[0;32m    764\u001b[0m msg \u001b[39m+\u001b[39m\u001b[39m=\u001b[39m \u001b[39m'\u001b[39m\u001b[39m\\n\u001b[39;00m\u001b[39m'\u001b[39m\u001b[39m.\u001b[39mjoin(parsed_def\u001b[39m.\u001b[39msource\u001b[39m.\u001b[39msplit(\u001b[39m\"\u001b[39m\u001b[39m\\n\u001b[39;00m\u001b[39m\"\u001b[39m)[:\u001b[39m3\u001b[39m])\n\u001b[0;32m    765\u001b[0m msg \u001b[39m+\u001b[39m\u001b[39m=\u001b[39m \u001b[39m\"\u001b[39m\u001b[39m <- Expecting `pass` or `...` here!\u001b[39m\u001b[39m\\n\u001b[39;00m\u001b[39m\"\u001b[39m \u001b[39m+\u001b[39m _OVERLOAD_EXAMPLE\n\u001b[1;32m--> 766\u001b[0m \u001b[39mraise\u001b[39;00m \u001b[39mRuntimeError\u001b[39;00m(msg)\n\n\u001b[1;31mRuntimeError\u001b[0m: Only `pass` statement or `...` can be the body of overload declaration:\n@torch.jit._overload  # noqa: F811\ndef matmul(src, other, reduce):  # noqa: F811\n    print(\"inside the sparse package matmul function\") <- Expecting `pass` or `...` here!\n\nExample usage of overload function:\n@torch.jit._overload\ndef my_function(x: type0) -> type0: # decl 1\n    pass\n\n@torch.jit._overload\ndef my_function(x: type1) -> type1: # decl 2\n    pass\n\ndef my_function(x):                 # implementation\n    if isinstance(x, type0):\n        return x\n    elif isinstance(x, type1):\n        return x\n"
}
